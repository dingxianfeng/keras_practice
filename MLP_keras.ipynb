# %%
#训练一个多层感知器
import tensorflow as tf
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense,Dropout,Activation
from keras.optimizers import Adam

batch_size = 128
num_classes = 10
epochs = 20

(x_train,y_train),(x_test,y_test) = mnist.load_data()


x_train = x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0],'train samples')
print(x_test.shape[0],'test samples')

y_train = keras.utils.to_categorical(y_train,num_classes)
y_test = keras.utils.to_categorical(y_test,num_classes)

model = Sequential()
model.add(Dense(512,activation='relu',input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes))
model.add(Activation(tf.nn.softmax))

model.summary()
model.compile(loss='categorical_crossentropy',optimizer=Adam(),metrics=['accuracy'])
history = model.fit(x_train,y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test,y_test))
score = model.evaluate(x_test,y_test,verbose=0)
print('Test loss: ',score[0])
print('Test accuracy: ',score[1])
# Out:
# 60000 train samples
# 10000 test samples
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                5130
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 13s 214us/step - loss: 0.2471 - acc: 0.9262 - val_loss: 0.1026 - val_acc: 0.9670
# Epoch 2/20
# 60000/60000 [==============================] - 13s 211us/step - loss: 0.1008 - acc: 0.9683 - val_loss: 0.0764 - val_acc: 0.9765
# Epoch 3/20
# 60000/60000 [==============================] - 13s 211us/step - loss: 0.0718 - acc: 0.9778 - val_loss: 0.0729 - val_acc: 0.9781
# Epoch 4/20
# 60000/60000 [==============================] - 13s 213us/step - loss: 0.0555 - acc: 0.9825 - val_loss: 0.0658 - val_acc: 0.9799
# Epoch 5/20
# 60000/60000 [==============================] - 13s 211us/step - loss: 0.0464 - acc: 0.9854 - val_loss: 0.0777 - val_acc: 0.9776
# Epoch 6/20
# 60000/60000 [==============================] - 13s 212us/step - loss: 0.0396 - acc: 0.9875 - val_loss: 0.0675 - val_acc: 0.9802
# Epoch 7/20
# 60000/60000 [==============================] - 13s 213us/step - loss: 0.0347 - acc: 0.9880 - val_loss: 0.0674 - val_acc: 0.9815
# Epoch 8/20
# 60000/60000 [==============================] - 13s 212us/step - loss: 0.0288 - acc: 0.9905 - val_loss: 0.0663 - val_acc: 0.9816
# Epoch 9/20
# 60000/60000 [==============================] - 13s 214us/step - loss: 0.0274 - acc: 0.9909 - val_loss: 0.0613 - val_acc: 0.9835
# Epoch 10/20
# 60000/60000 [==============================] - 13s 214us/step - loss: 0.0246 - acc: 0.9918 - val_loss: 0.0691 - val_acc: 0.9832
# Epoch 11/20
# 60000/60000 [==============================] - 13s 213us/step - loss: 0.0232 - acc: 0.9922 - val_loss: 0.0761 - val_acc: 0.9819
# Epoch 12/20
# 60000/60000 [==============================] - 13s 213us/step - loss: 0.0228 - acc: 0.9926 - val_loss: 0.0697 - val_acc: 0.9813
# Epoch 13/20
# 60000/60000 [==============================] - 13s 213us/step - loss: 0.0203 - acc: 0.9930 - val_loss: 0.0691 - val_acc: 0.9839
# Epoch 14/20
# 60000/60000 [==============================] - 13s 213us/step - loss: 0.0186 - acc: 0.9938 - val_loss: 0.0788 - val_acc: 0.9816
# Epoch 15/20
# 60000/60000 [==============================] - 13s 213us/step - loss: 0.0173 - acc: 0.9939 - val_loss: 0.0694 - val_acc: 0.9847
# Epoch 16/20
# 60000/60000 [==============================] - 13s 213us/step - loss: 0.0170 - acc: 0.9944 - val_loss: 0.0769 - val_acc: 0.9836
# Epoch 17/20
# 60000/60000 [==============================] - 13s 213us/step - loss: 0.0214 - acc: 0.9927 - val_loss: 0.0802 - val_acc: 0.9821
# Epoch 18/20
# 60000/60000 [==============================] - 13s 213us/step - loss: 0.0150 - acc: 0.9951 - val_loss: 0.0684 - val_acc: 0.9849
# Epoch 19/20
# 60000/60000 [==============================] - 13s 213us/step - loss: 0.0148 - acc: 0.9954 - val_loss: 0.0758 - val_acc: 0.9837
# Epoch 20/20
# 60000/60000 [==============================] - 13s 218us/step - loss: 0.0154 - acc: 0.9949 - val_loss: 0.0868 - val_acc: 0.9820
# Test loss:  0.08677764379240871
# Test accuracy:  0.982
